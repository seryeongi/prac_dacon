# %% [markdown]
# <a href="https://colab.research.google.com/github/SeryeongLee/-/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 신용카드 사용자 연체 예측 AI 경진대회

# %% [markdown]
# **overview**
# 신용카드 사용자 데이터를 보고 사용자의 대금 연체 정도를 예측하는 알고리즘 개발

# %% [markdown]
# **Data Fields**
#
# index
#
#
# gender: 성별
#
#
# car: 차량 소유 여부
#
#
# reality: 부동산 소유 여부
#
#
# child_num: 자녀 수
#
#
# income_total: 연간 소득
#
#
# income_type: 소득 분류
#
#
# 							['Commercial associate', 'Working', 'State servant', 'Pensioner', 'Student']
#
#
#
# edu_type: 교육 수준
#
#
# 							['Higher education' ,'Secondary / secondary special', 'Incomplete higher', 'Lower secondary', 'Academic degree']
#
#
#
# family_type: 결혼 여부
#
#
# 							['Married', 'Civil marriage', 'Separated', 'Single / not married', 'Widow']
#
#
#
# house_type: 생활 방식
#
#
# 							['Municipal apartment', 'House / apartment', 'With parents',
#
#
#
# 							 'Co-op apartment', 'Rented apartment', 'Office apartment']
#
#
#
# DAYS_BIRTH: 출생일
#
#
# 							데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전에 태어났음을 의미
#
#
#
# DAYS_EMPLOYED: 업무 시작일
#
#
# 							데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 하루 전부터 일을 시작함을 의미
#
#
#
# 							양수 값은 고용되지 않은 상태를 의미함
#
#
#
# FLAG_MOBIL: 핸드폰 소유 여부
#
#
# work_phone: 업무용 전화 소유 여부
#
#
# phone: 가정용 전화 소유 여부
#
#
# email: 이메일 소유 여부
#
#
# occyp_type: 직업 유형
#
#
# family_size: 가족 규모
#
#
# begin_month: 신용카드 발급 월
#
#
# 							데이터 수집 당시 (0)부터 역으로 셈, 즉, -1은 데이터 수집일 한 달 전에 신용카드를 발급함을 의미
#
#
#
#
#
#
#
# credit: 사용자의 신용카드 대금 연체를 기준의 신용도(타겟변수)
#
#
# 							=> 낮을 수록 높은 신용의 신용카드 사용자를 의미함

# %% [markdown]
# ## 라이브러리 및 데이터
# ## Library & Data

# %%
# import packages
import pylab

""""
pylab = matplotlib.pyplot + numpy
        - interactive 환경 (shell, ipython 등) 에서만 pylab 사용하고, 
        프로그래밍시에는  각각 matplotlib.pyplot , numpy 로 구분하여 사용해라.
"""

import numpy as np
import pandas as pd
import seaborn as sns
# from scipy import stats # 확률분포 분석
import missingno as msno # 결측치 시각화
import matplotlib.pyplot as plt
import warnings
# 경고를 끈다
pd.options.mode.chained_assignment = None
# 경고 메세지 무시
warnings.filterwarnings("ignore", category=DeprecationWarning)
# 노트북을 실행한 브라우저에서 그림 등을 볼 수 있게 함
# %matplotlib inline
from sklearn.model_selection import StratifiedKFold
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ### load data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train=pd.read_csv("/content/drive/MyDrive/creditcard/open/train.csv")
test=pd.read_csv("/content/drive/MyDrive/creditcard/open/test.csv")
submission=pd.read_csv("/content/drive/MyDrive/creditcard/open/sample_submission.csv")

pd.set_option('display.max_columns',500)

# %% [markdown]
# # [데이터 살펴보기]

# %%
train.shape, test.shape
# Out:
# ((26457, 20), (10000, 19))

# %%
train.head()

# %%
test.head()

# %%
train.info()

# %%
# 전체 피처의 타입 확인
print('\n전체 피처의 type \n', train.dtypes.value_counts())

# %%
# check train unique 
train_unique= train.apply(lambda x : x.unique())
train_unique

# %% [markdown]
# FLAG_MOBILE은 모두 1이다. 즉, 모두 핸드폰을 가지고 있다.
# family_size = child_num + adult_num 이겠지만 어른과 아이의 수가 신용도에 큰 영향은 없을 것으로 판단해 칼럼을 그냥 둔다.

# %% [markdown]
# ## 데이터 전처리
# ## Data Cleansing & Pre-Processing

# %% [markdown]
# 1. 결측치 제거

# %% [markdown]
# 결측치 확인

# %%
# 결측값 시각화로 확인
msno.matrix(train, figsize=(10,5))

# %%
train.isnull().sum()
# Out:
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %% [markdown]
# occyp_type에서 결측값이 존재한다.

# %%
train['occyp_type'].unique()
# Out:
# array([nan, 'Laborers', 'Managers', 'Sales staff',
#        'High skill tech staff', 'Core staff', 'Drivers', 'Medicine staff',
#        'Accountants', 'Realty agents', 'Security staff', 'Cleaning staff',
#        'Private service staff', 'Cooking staff', 'Secretaries',
#        'HR staff', 'IT staff', 'Low-skill Laborers',
#        'Waiters/barmen staff'], dtype=object)

# %%
# occyp_type 칼럼 삭제하기
# 이유는 occyp_type이 factor형태의 데이터이기 때문에 값을 대체하기 어렵기 때문이다.
# 또한 결측값이 8171로 많이 존재하기 때문이다.
train=train.drop("occyp_type",axis=1)
# test set에도 똑같이 적용
test=test.drop("occyp_type",axis=1)

# %%
# occyp_type 제거 후 결측치 확인
train.isnull().sum()
# Out:
# index            0
# gender           0
# car              0
# reality          0
# child_num        0
# income_total     0
# income_type      0
# edu_type         0
# family_type      0
# house_type       0
# DAYS_BIRTH       0
# DAYS_EMPLOYED    0
# FLAG_MOBIL       0
# work_phone       0
# phone            0
# email            0
# family_size      0
# begin_month      0
# credit           0
# dtype: int64

# %% [markdown]
# 결측치 제거됨
# 고민할 점 -> NaN으로 대체하면 어떻게 되는거지?

# %% [markdown]
# 2. target 변수 credit 비율 살펴보기

# %%
f, ax = plt.subplots(1, 2, figsize=(16,8))
sns.set_theme(style="darkgrid")
train['credit'].value_counts().plot.pie(explode=[0,0.1, 0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('credit ratio')
sns.countplot( x='credit',data=train,ax=ax[1])
ax[1].set_title('credit')
plt.show()

# %% [markdown]
# credit이 낮을수록 높은 신용을 뜻하므로 낮은 신용을 가진 사람들이 많다.

# %% [markdown]
# #### 3. 명목형 EDA
# 각 명목형 변수 별 credit

# %% [markdown]
# 명목형 변수는 따로 처리할 게 없는 듯하다.

# %% [markdown]
# #### 4. 수치형 EDA

# %% [markdown]
# 수치형 변수 간의 상관관계

# %%
plt.figure(figsize=(16,9))
sns.heatmap(train.corr(),annot=True,fmt="0.2f")

# %% [markdown]
# family size와 child_num의 상관계수는 0.89로 높다

# %% [markdown]
# ### 피처 엔지니어링

# %% [markdown]
# 수치형 변수의 분포를 histogram으로 확인

# %%
g = train.set_index('index').hist(bins=30,figsize=(20,15))
plt.suptitle("numerical variable distribution",fontsize='xx-large',fontweight=800)
plt.show()

# %% [markdown]
# income_total은 신용도에 영향을 끼치는 중요한 속성으로 판단되어 정규분포 형태로 변환해준다.

# %% [markdown]
# 1) income_total 변환

# %%
tr_it=train['income_total']
sns.distplot(tr_it)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# right-skewed distribution -> 로그 변환으로 정규 분포 형태로 만들어주기

# %%
tr_it_log = np.log1p(tr_it)
sns.distplot(tr_it_log)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 전보다 왜곡 정도가 좋아졌다.

# %%
# test set에도 적용
te_it=test['income_total']
te_it_log = np.log1p(te_it)
fig, (ax1,ax2) = plt.subplots(ncols=2)
fig.set_size_inches(8,4)
sns.distplot(te_it,ax=ax1)
sns.distplot(tr_it_log,ax=ax2)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 이상치 확인

# %%
fig, (ax1,ax2,ax3) = plt.subplots(ncols=3)
fig.set_size_inches(20, 10)
sns.boxplot(data=train,y="credit",orient="v",ax=ax1)
sns.boxplot(data=train,y="family_size",orient="v",ax=ax2)
sns.boxplot(data=train,y="child_num",orient="v",ax=ax3)
ax1.set(ylabel='Credit',title="Box Plot On Credit")
ax2.set(xlabel='Family size', ylabel='Count',title="Box Plot On Family Size")
ax3.set(xlabel='Child Num', ylabel='Count',title="Box Plot On Child Num")
# Out:
# [Text(0, 0.5, 'Count'),
#  Text(0.5, 0, 'Child Num'),
#  Text(0.5, 1.0, 'Box Plot On Child Num')]

# %% [markdown]
# 2) child_num

# %%
# check child num counts
train['child_num'].value_counts(sort=True)
# Out:
# 0     18340
# 1      5386
# 2      2362
# 3       306
# 4        47
# 5        10
# 14        3
# 7         2
# 19        1
# Name: child_num, dtype: int64

# %%
train.loc[train['child_num']>=3,'child_num']=3
test.loc[test['child_num']>=3,'child_num']=3

# %%
# 3 이상 값 합친 후 확인
train['child_num'].value_counts()
# Out:
# 0    18340
# 1     5386
# 2     2362
# 3      369
# Name: child_num, dtype: int64

# %% [markdown]
# child_numd은 이상값을 처리해 사용하는 것이 좋을 것 같지만
# family_size는 신용도에 영향을 미칠 것 같아 이상값을 처리하지 않았다.

# %% [markdown]
# 3) 연단위 변수들

# %%
train=pd.read_csv('/content/drive/MyDrive/creditcard/open/train.csv')

# %%
# 양수(일하지 않는 사람) 0으로 대체
train['DAYS_EMPLOYED']= train['DAYS_EMPLOYED'].map(lambda x: 0 if x>0 else x)

# %%
train['EMPLOYED']= train.DAYS_EMPLOYED.apply(lambda x: abs(x/360) )
train['age']= train.DAYS_BIRTH.apply(lambda x: abs(x/360) ).astype(int)
train['begin_month']= train.begin_month.apply(lambda x: abs(x) ).astype(int)

# %%
# 나이는 대별로 나누기
train['EMPLOYED']
# Out:
# 0        13.080556
# 1         4.277778
# 2        12.316667
# 3         5.811111
# 4         5.847222
#            ...
# 26452     5.511111
# 26453     6.875000
# 26454     5.597222
# 26455     0.297222
# 26456     2.813889
# Name: EMPLOYED, Length: 26457, dtype: float64

# %%
g = train.set_index('index').hist(bins=30,figsize=(20,15))
plt.suptitle("numerical variable distribution",fontsize='xx-large',fontweight=800)
plt.show()

# %% [markdown]
# 원-핫 인코딩

# %%
train_e = train.copy()
test_e = test.copy()

# %%
obj_col = []
for col in train.columns:
  if train[col].dtype=='object':
    obj_col.append(col)

# %%
train_ohe=pd.get_dummies(train,columns=obj_col)
test_ohe=pd.get_dummies(test,columns=obj_col)
train_e= train_ohe.iloc[:12]
test_e=test_ohe.iloc[:,12]

# %% [markdown]
# def dummy_data(data, columns):
#     for column in columns:
#         data = pd.concat([data, pd.get_dummies(data[column], prefix = column)], axis=1)
#         data = data.drop(column, axis=1)
#     return data
# train_dummy = dummy_data(train1, obj_col)
# test_dummy = dummy_data(test1, obj_col)

# %%
print(train_ohe.shape,test_ohe.shape)
# Out:
# (26457, 41) (10000, 38)

# %%
train=pd.concat([train,train.iloc[:,12]],axis=1)

# %%
# 훈련을 하기 전 필요없는 칼럼을 삭제
x_train=train_ohe.drop(["index",'credit'],axis=1, inplace=True)
x_test=test_ohe.drop("index",axis=1,inplace=True)
y_train=train[['credit']]

# %%
train
# Out:
#        index gender car reality  child_num  income_total  \
# 0          0      F   N       N          0      202500.0
# 1          1      F   N       Y          1      247500.0
# 2          2      M   Y       Y          0      450000.0
# 3          3      F   N       Y          0      202500.0
# 4          4      F   Y       Y          0      157500.0
# ...      ...    ...  ..     ...        ...           ...
# 26452  26452      F   N       N          2      225000.0
# 26453  26453      F   N       Y          1      180000.0
# 26454  26454      F   Y       N          0      292500.0
# 26455  26455      M   N       Y          0      171000.0
# 26456  26456      F   N       N          0       81000.0
#
#                 income_type                       edu_type  \
# 0      Commercial associate               Higher education
# 1      Commercial associate  Secondary / secondary special
# 2                   Working               Higher education
# 3      Commercial associate  Secondary / secondary special
# 4             State servant               Higher education
# ...                     ...                            ...
# 26452         State servant  Secondary / secondary special
# 26453               Working               Higher education
# 26454               Working  Secondary / secondary special
# 26455               Working              Incomplete higher
# 26456               Working  Secondary / secondary special
#
#                 family_type           house_type  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                   Married  Municipal apartment      -13899          -4709
# 1            Civil marriage    House / apartment      -11380          -1540
# 2                   Married    House / apartment      -19087          -4434
# 3                   Married    House / apartment      -15088          -2092
# 4                   Married    House / apartment      -15037          -2105
# ...                     ...                  ...         ...            ...
# 26452               Married    House / apartment      -12079          -1984
# 26453             Separated    House / apartment      -15291          -2475
# 26454        Civil marriage         With parents      -10082          -2015
# 26455  Single / not married    House / apartment      -10145           -107
# 26456        Civil marriage    House / apartment      -19569          -1013
#
#        FLAG_MOBIL  work_phone  phone  email      occyp_type  family_size  \
# 0               1           0      0      0             NaN          2.0
# 1               1           0      0      1        Laborers          3.0
# 2               1           0      1      0        Managers          2.0
# 3               1           0      1      0     Sales staff          2.0
# 4               1           0      0      0        Managers          2.0
# ...           ...         ...    ...    ...             ...          ...
# 26452           1           0      0      0      Core staff          4.0
# 26453           1           0      0      0             NaN          2.0
# 26454           1           0      0      0      Core staff          2.0
# 26455           1           0      0      0        Laborers          1.0
# 26456           1           0      0      0  Security staff          2.0
#
#        begin_month  credit  FLAG_MOBIL
# 0             -6.0     1.0           1
# 1             -5.0     1.0           1
# 2            -22.0     2.0           1
# 3            -37.0     0.0           1
# 4            -26.0     2.0           1
# ...            ...     ...         ...
# 26452         -2.0     1.0           1
# 26453        -47.0     2.0           1
# 26454        -25.0     2.0           1
# 26455        -59.0     2.0           1
# 26456         -9.0     2.0           1
#
# [26457 rows x 21 columns]

# %%
print(x_train)
# Out:
# None

# %% [markdown]
# ## 데이터 모델링

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.metrics import f1_score
from tensorflow.keras.utils import to_categorical

X_train, X_val, y_train, y_val = train_test_split(train_ohe, test_ohe, 
                                                    stratify=train_y, test_size=0.25,
                                                    random_state = 10086)

print("Train set: ")
print(X_train.shape)
print(y_train.shape)
print("===========")
print("Validation set: ")
print(X_val.shape)
print(y_val.shape)


clf=RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred=clf.predict_proba(X_val)

print(f"log_loss: {log_loss(to_categorical(y_val['credit']), y_pred)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-208-ff33efec063d> in <module>()
#       4 from tensorflow.keras.utils import to_categorical
#       5
# ----> 6 X_train, X_val, y_train, y_val = train_test_split(train_ohe, test_ohe,
#       7                                                     stratify=train_y, test_size=0.25,
#       8                                                     random_state = 10086)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ## 모델 학습 및 검증
# ## Model Tuning & Evaluation
